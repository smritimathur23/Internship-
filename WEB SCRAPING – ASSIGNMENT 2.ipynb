# %%
# !pip install selenium

# %%
import selenium 
from selenium import webdriver 
import warnings 
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By 
import time

# %%
#Downloading the webdriver for the web browser.

# %%
driver = webdriver.Chrome(r"C:\Users\sudes\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %% [markdown]
# Question 1.
#
# Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.
#
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME, "suggestor-input")
designation.send_keys('Data Analyst')

# %%
location = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search = driver.find_element(By.CLASS_NAME, "qsbSubmit")
search.click()

# %%
job_title = []
job_location = []
company_name = []
expirence_required = []

# %%
#Scrapping the details now one by one. 

title_tag = driver.find_elements(By.XPATH, '//a[@class= "title fw500 ellipsis"]')
for i in title_tag[0:10]:
    title = i.text
    job_title.append(title)

# %%
company_tags = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]: 
    company = i.text
    company_name.append(company)

# %%
job_tags = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in job_tags[0:10]: 
    location = i.text
    job_location.append(location)

# %%
exp_tags = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in exp_tags[0:10]: 
    exp = i.text
    expirence_required.append(exp)

# %%
print(len(job_title), len(job_location), len(company_name), len(expirence_required))
# Out:
# 10 10 10 10

# %%
#Creating DataFrame of the data scrapped above.

# %%
import pandas as pd 
df = pd.DataFrame({'Job Title':job_title, 'Location': job_location, 'Company': company_name, 'Expirenece required': expirence_required})

# %%
df
# Out:
#                                            Job Title  \
# 0                                Senior Data Analyst
# 1                                       Data Analyst
# 2  Hiring For Data Analyst (DA)/ Team Lead (TL) -...
# 3  Call For Clinical Data Analyst - Hyd/Bangalore...
# 4                Payroll Transformation Data Analyst
# 5                Payroll Transformation Data Analyst
# 6            Master Data Management Business Analyst
# 7  Data Analytics and Interpretation Business Ana...
# 8                                    HR Data Analyst
# 9                                       Data Analyst
#
#                                             Location            Company  \
# 0                       Bangalore/Bengaluru, Chennai         Latentview
# 1                                Bangalore/Bengaluru                Jar
# 2  Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...          Cognizant
# 3  Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...          Cognizant
# ...

# %% [markdown]
# Question 2.
#
# Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME, "suggestor-input ")
designation.send_keys('Data Scientist')

# %%
location = driver.find_element(By.XPATH, '//*[@id="root"]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys('Bangalore')

# %%
search = driver.find_element(By.CLASS_NAME, "qsbSubmit")
search.click()

# %%
job_title = []
job_location = []
company_name = []

# %%
title_tags = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]: 
    title = i.text
    job_title.append(title)

# %%
location_tags = driver.find_elements(By.XPATH, '//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]: 
    loc = i.text
    job_location.append(loc)

# %%
company_tags = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]: 
    com = i.text
    company_name.append(com)

# %%
print(len(job_title), len(job_location), len(company_name), len(expirence_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd 
df1 = pd.DataFrame({'Job Title':job_title, 'Location': job_location, 'Company': company_name, 'Expirenece required': expirence_required})

# %%
df1
# Out:
#                                            Job Title  \
# 0                            Data Science Specialist
# 1                               Data Science Manager
# 2  Mongodb Database Administrator, Maria DB or Ca...
# 3                   Analystics & Modeling Specialist
# 4                   Assistant Manager - Data Science
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7                              Senior Data Scientist
# 8            Data Scientist: Artificial Intelligence
# 9                  Industry X - Software Engineering
#
#                                             Location                  Company  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 2  Bangalore/Bengaluru, Hyderabad/Secunderabad, P...                  Mphasis
# ...

# %% [markdown]
# Question 3. In this question you have to scrape data using the filters available on the webpage as shown below:
#
# 1. You have to use the location and salary filter.
# 2. You have to scrape data for “Data Scientist” designation for first 10 job results.
# 3. You have to scrape the job-title, job-location, company name, experience required.
# 4. The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs

# %%
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME, "suggestor-input ")
designation.send_keys('Data Scientist')

# %%
search = driver.find_element(By.CLASS_NAME, "qsbSubmit")
search.click()

# %%
lfilter = driver.find_element(By.XPATH, '//*[@id="root"]/div[4]/div/section[1]/div[2]/div[5]/div[2]/div[3]/label/p/span[1]')
lfilter.click()

# %%
salfilter = driver.find_element(By.XPATH, '//*[@id="root"]/div[4]/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]')
salfilter.click()

# %%
job_title = []
job_location = []
company_name = []
Expirence_Recquired = []

# %%
title_tag = driver.find_elements(By.XPATH, '//a[@class="title fw500 ellipsis"]')
for i in title_tag[0:10]: 
    title = i.text
    job_title.append(title)

# %%
loc_tag = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loc_tag[0:10]: 
    loc = i.text
    job_location.append(loc)

# %%
name_tag = driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in name_tag[0:10]: 
    name = i.text
    company_name.append(name)

# %%
exp_tags = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in exp_tags[0:10]: 
    exp = i.text
    Expirence_Recquired.append(exp)

# %%
import pandas as pd 
df2 = pd.DataFrame({'Job Title':job_title, 'Location': job_location, 'Company': company_name, 'Expirenece required': expirence_required})

# %%
df2
# Out:
#                                    Job Title  \
# 0                             Data Scientist
# 1            DigitalBCG GAMMA Data Scientist
# 2                        Lead Data Scientist
# 3                             Data Scientist
# 4                             Data Scientist
# 5        Data Scientist / Chat-bot Developer
# 6          Data Scientist - Engine Algorithm
# 7  Data Activation Specialist - Adobe Target
# 8                             Data Scientist
# 9                             Data Scientist
#
#                                             Location                  Company  \
# 0                 Noida, Nagpur, Bangalore/Bengaluru              GlobalLogic
# 1                     New Delhi, Bangalore/Bengaluru  Boston Consulting Group
# 2         Noida(Sector-59 Noida)\n(WFH during Covid)  R Systems International
# 3                                   Gurgaon/Gurugram               IHS Markit
# ...

# %% [markdown]
# Questio 4.
#
# Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price
# The attributes which you have to scrape is ticked marked in the below image.

# %% [markdown]
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url : https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and
# click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the
# required data as usual.

# %%
driver.get("https://www.flipkart.com/")

# %%
sung = driver.find_element(By.CLASS_NAME, '_3704LK')
sung.send_keys("sunglasses")

# %%
search = driver.find_element(By.CLASS_NAME, "L0Z3Pu")
search.click()

# %%
Brand = []
ProductDescription = []
Price = []

# %%
brand_tag = driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
for i in brand_tag[0:100]: 
    br = i.text
    Brand.append(br)

# %%
prdp_tag = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in prdp_tag[0:100]: 
    pr = i.text
    ProductDescription.append(pr)

# %%
price_tag = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tag[0:100]: 
    price = i.text
    Price.append(price)

# %%
print(len(Brand), len(ProductDescription), len(Price))
# Out:
# 40 40 40

# %%
df4 = pd.DataFrame({'Brand': Brand, 'Product Description': ProductDescription, 'Price': Price})

# %%
df4
# Out:
#                 Brand                                Product Description  \
# 0             CARRERA                 Others Rectangular Sunglasses (58)
# 1             CARRERA                     Others Aviator Sunglasses (57)
# 2            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 3   SHAAH COLLECTIONS                UV Protection Round Sunglasses (54)
# 4               NuVew              UV Protection Aviator Sunglasses (57)
# 5               Bedst                       Others Round Sunglasses (59)
# 6           New Specs          UV Protection Oval Sunglasses (Free Size)
# 7       VINCENT CHASE     Polarized, UV Protection Round Sunglasses (51)
# 8            Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 9   SHAAH COLLECTIONS   UV Protection Rectangular Sunglasses (Free Size)
# 10  SHAAH COLLECTIONS              UV Protection Aviator Sunglasses (54)
# 11     ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...
# ...

# %% [markdown]
# Question 5.
#
# Scrape 100 reviews data from flipkart.com for iphone11 phone.
# This task will be done in following steps:
# 1. First get the webpage https://www.flipkart.com/
# 2. Enter “iphone 11” in “Search” field .
# 3. Then click the search button.
# You will reach to the below shown webpage .

# %% [markdown]
# As shown in the above page you have to scrape the tick marked attributes.These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100 reviews.
# Note: All the steps required during scraping should be done through code only and not manually

# %%
driver.get("https://www.flipkart.com/")

# %%
sung = driver.find_element(By.CLASS_NAME, '_3704LK')
sung.send_keys("iphone11")

search = driver.find_element(By.CLASS_NAME, "L0Z3Pu")
search.click()

# %%
iphone = driver.find_element(By.CLASS_NAME, '_4rR01T')
iphone.click()

# %%
Ratings = []
Review_Summary = []
Full_Review = []

# %%
rating_tag = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tag[0:100]: 
    rate = i.text
    Ratings.append(rate)

# %%
summ_tag = driver.find_elements(By.XPATH, '//p[@class="_2-N8zT"]')
for i in summ_tag[0:100]: 
    summary = i.text
    Review_Summary.append(summary)

# %%
reveiw_tags = driver.find_elements(By.XPATH, '//div[@class="t-ZTKy"]')
for i in reveiw_tags[0:100]: 
    rev = i.text
    Full_Review.append(rev)

# %%
print(len(Ratings), len(Review_Summary), len(Full_Review))
# Out:
# 10 10 10

# %%
df5 = pd.DataFrame({'Ratings': Ratings, 'Reveiw Summary': Review_Summary, 'Full Review': Full_Review})

# %%
df5
# Out:
#   Ratings                         Reveiw Summary  \
# 0       5                       Perfect product!
# 1       5                               Terrific
# 2       3  Good phone but not for the power user
# 3       5                                 Super!
# 4       4                        Value-for-money
# 5       5                              Wonderful
# 6       4                   Good quality product
# 7       5                       Perfect product!
# 8       5                              Fabulous!
# 9       5                  Mind-blowing purchase
#
#                                          Full Review
# 0  After using 3 years mobile review. Excellent &...
# 1  I am using the phone for last 5 years and foun...
# 2  Apple's iPhone series have been known for thei...
# 3  This review is after 6 year of purchasing this...
# 4  I'm Really happy with the product\nDelivery wa...
# 5                         Nice product..just love it
# ...

# %% [markdown]
# Question 6.
#
# Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the
# search field.
# You have to scrape 4 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price
# As shown in the below image, you have to scrape the tick marked attributes

# %%
driver.get("https://www.flipkart.com/")

# %%
sung = driver.find_element(By.CLASS_NAME, '_3704LK')
sung.send_keys("sneakers")

search = driver.find_element(By.CLASS_NAME, "L0Z3Pu")
search.click()

# %%
sneaker = driver.find_element(By.CLASS_NAME, '_2r_T1I')
sneaker.click()

# %%
Brand = []
Productdes = []
Price = []

# %%
brand_tag = driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
for i in brand_tag[0:100]: 
    br = i.text
    Brand.append(br)

# %%
des_tag = driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
for i in des_tag[0:100]: 
    des = i.text
    Productdes.append(des)

# %%
price_tag = driver.find_elements(By.XPATH, '//div[@class="_30jeq3"]')
for i in price_tag[0:100]: 
    pr = i.text
    Price.append(pr)

# %%
print(len(Brand), len(Productdes), len(Price))
# Out:
# 40 40 40

# %%
df6 = pd.DataFrame({'Brand': Brand, 'Product Description': Productdes, 'Price': Price})

# %%
df6
# Out:
#                   Brand                                Product Description  \
# 0                 asian  Newton-01 Men's Lightweight Running Shoes Snea...
# 1              RapidBox                                   Sneakers For Men
# 2              RED TAPE                                   Sneakers For Men
# 3                BRUTON      Modern Trendy Sneakers Shoes Sneakers For Men
# 4                BRUTON  Lightweight Pack Of 1 Trendy Sneakers Sneakers...
# 5   World Wear Footwear  Latest Collection-1215 Stylish Casual Sports S...
# 6              RED TAPE                                   Sneakers For Men
# 7                 BIRDE        Premium Casual Shoes White Sneakers For Men
# 8                Labbin                                   Sneakers For Men
# 9                BRUTON             Lattest Sneakers Shoe Sneakers For Men
# 10  World Wear Footwear  Latest Collection Black-349 Trendy & Stylish C...
# ...

# %% [markdown]
# Question 7.
#
# Go to the link - https://www.myntra.com/shoes
# Set second Price filter and Color filter to “Black”, as shown in the below image.
# And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe
# description, price of the shoe as shown in the below image.

# %%
driver.get("https://www.myntra.com/shoes")

# %% [markdown]
# Note: The website is not allowing the inspection.

# %% [markdown]
# Question 8.
#
# Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” as shown in the below image:
#
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributesfor each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
driver.get("https://www.amazon.in/")

# %%
product = driver.find_element(By.XPATH, "//input[@class='nav-input nav-progressive-attribute']")
product.send_keys("laptop")

# %%
search = driver.find_element(By.XPATH, '//*[@id="nav-search-bar-form"]/div[3]/div')
search.click()

# %%
cpuf = driver.find_element(By.XPATH, '/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[5]/li[13]/span/a/span')
cpuf.click()

# %%
Title = []
Ratings = []
Price = []

# %%
title_tag = driver.find_elements(By.XPATH, '//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in title_tag[0:10]:
    titlet = i.text
    Title.append(titlet)

# %%
rate_tag = driver.find_elements(By.XPATH, "//span[@data-hook='acr-average-stars-rating-text']")
for i in rate_tag[0:10]: 
    rate = i.text 
    Ratings.append(rate)

# %%
price_tag = driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for i in price_tag[0:10]: 
    pr = i.text
    Price.append(pr)

# %%
print(len(Title), len(Ratings), len(Price))
# Out:
# 10 0 10

# %%
df7 = pd.DataFrame({'Title': Title, 'Price': Price})

# %%
df7
# Out:
#                                                Title     Price
# 0  LG Gram Intel Evo 11th Gen Core i7 17"(43cm)Ul...    91,990
# 1  Fujitsu UH-X 11th Gen Intel Core i7 13.3" FHD ...  1,00,000
# 2  ASUS Zenbook 13 OLED, 13.3-inch (33.78 cms) FH...    74,990
# 3  ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, I...    64,990
# 4  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...    80,000
# 5  HP Pavilion x360 11th Gen Intel Core i7 14 inc...    80,990
# 6  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....    77,990
# 7  Lenovo Yoga 7i 11th Gen Intel Core i7-1165G7 1...  1,12,950
# 8  Hp Pavilion X360 11Th Gen Intel Core I7 14 Inc...    82,490
# 9  ASUS Zenbook 13 OLED, 13.3-inch (33.78 cms) FH...    69,990

# %% [markdown]
# Question 10.
#
# Write a python program to scrape the salary data for Data Scientist designation.
# You have to scrape Company name, Number of salaries, Average salary, Minsalary, Max Salary.
# The above task will be, done as shown in the below steps:
# 1. First get the webpage https://www.ambitionbox.com/
# 2. Click on the salaries option as shown in the image.
# 3. After reaching to the following webpage, In place of “Search Job Profile” enters “Data Scientist” and
# then click on “Data Scientist”.
# You have to scrape the data ticked in the above image.
# 4. Scrape the data for the first 10 companies. Scrape the company name, total salary record, average
# salary, minimum salary, maximum salary, experience required.
# 5. Store the data in a dataframe.

# %%
driver.get("https://www.ambitionbox.com/")

# %%
click_on_salaries = driver.find_element(By.CLASS_NAME,"subNavWrapper")
click_on_salaries.click()

# %%
Note: Website is not working accuretly.
